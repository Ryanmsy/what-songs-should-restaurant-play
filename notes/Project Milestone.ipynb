# %% [markdown]
# Since the the two datasets are huge, do we need all the rows and columns?

# %%
Milestone 1 = Redudndacy and removing

Perform Covariance matrix / correlation 

covariance matrix = compares the variance of each variable vs the covairance (does x and y variable move in the same direction)

the number of columns = number of rows becauses it is a square matrix, so if we have 5 features, we have 5 rows and 5 columns 

the diagonal elements are the variances of each variable (x,y,z)

# %%
how do we perform covrance matrix? 

remove all category data so that dataset (X) consist of only continous varialbes 

then run coorelation amtrix 

Correlation map Spotify 

can we visualize the subspace, 
correlation map yelp 



PCA - find which columns are the most important 

SVD 

Eigen values and vectors

# %%
Milestone 2 = Core engine 

Similarity Modeling: You need a mathematical way to compare a restaurant's profile to a song's audio profile. You will likely use Cosine Similarity or a K-Nearest Neighbors (KNN) algorithm to calculate the distance between a Yelp venue's feature vector and the Spotify tracks' feature vectors.

Clustering (Optional but Recommended): Comparing every single song to every single restaurant is computationally heavy. You can group similar songs and similar venues into "vibe clusters" using algorithms like K-Means or DBSCAN. For example, one cluster might organically form around "dark, expensive, acoustic."

Evaluation & Tuning: How do you know the pairings actually make sense? You'll need to define a testing phase. This usually involves manually spot-checking the outputs to ensure a quiet coffee shop isn't getting paired with high-energy dubstep, and tweaking your feature weights accordingly.

API Development: Before you can deploy anything, your model needs a way to communicate. You will need to wrap your machine learning script in a lightweight web framework like FastAPI or Flask. This allows your system to receive a request (e.g., a Yelp ID) and return a response (e.g., a JSON list of recommended Spotify track IDs).

# %%
Milestone 3 = Deployment 
Container 
Docker 
Parallel Distrubtion 


If possible - improve code structure like using OOP / UV / Path Lib
